# %%
exec(open("Lopez_OOP_FinalProj_2026.py").read())

# %% [markdown]
# ## Put this file in the same directory as your python script. Change the name of the file in the next line to test your code.

# %% [markdown]
# # TEST SEQ CLASS

# %% [markdown]
# ## Make instance of Seq called 's' and test methods

# %%
s=Seq("  gATATAGGACctttaGGACCAC  ","my_gene","H.sapiens")
s.print_record()
s.make_kmers()
a=s.kmers
# Out:
# H.sapiens my_gene:   gATATAGGACctttaGGACCAC
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 s=Seq("  gATATAGGACctttaGGACCAC  ","my_gene","H.sapiens")
#       2 s.print_record()
# ----> 3 s.make_kmers()
#       4 a=s.kmers
#
# AttributeError: 'Seq' object has no attribute 'make_kmers'

# %%
t=Seq(" AGAGAGAGTGTTGT",'gene2','D')

# %%
t.print_record()
t.make_kmers()
b=t.kmers
out=set(a) & set(b)

# %%
print(s)
print(s.gene)
print(s.species)

# %%
s.make_kmers(5)
print(s.kmers)

# %%
print(s.fasta())

# %% [markdown]
# # TEST DNA CLASS

# %% [markdown]
# ## Make instance of DNA called 'd' and test methods

# %%
d=DNA("  -tcaaaGCGGCGGATCTCCCaaatga\n","my_dna","D.terebrans","AX5667")
d.print_info()

# %%
print(d)
print(d.analysis())
print(d.fasta())

# %%
rc=d.reverse_complement()
print(rc)

# %%
all_6_frames=d.six_frames()
print(all_6_frames)

# %% [markdown]
# # TEST RNA CLASS

# %% [markdown]
# ## Make instance of RNA called 'r' and test methods

# %%
r=RNA("  g?ATATAGGACctttaGGACCAC  ","my_rna","G.gallus","R5990999")
r.print_info()
print(r)

# %%
r.make_codons()
print(r.codons)

# %%
print(r.translate())

# %%
print(r.fasta())

# %% [markdown]
# # TEST Protein CLASS

# %% [markdown]
# ## Make instance of Protein called 'p' and test methods

# %%
p=Protein(" WCVALKKKCCYhhhhh-yyyrsQ\t","my_prot","D.melanogaster","56008009")
print(p)

# %%
print(p.fasta())

# %%
print(p.kmers)

# %%
p.kmers=[]
p.make_kmers(5)
print(p.kmers)

# %%
testp=Protein('VIKING','test','unknown',999)

# %%
print(testp)

# %%
testp.make_kmers(2)
print(testp.kmers)

# %%
x=testp.total_hydro()
print(x)

# %%
m=testp.mol_weight()
print(m)
